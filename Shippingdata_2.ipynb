# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("G:\\DATA SCIENCE\\PROJECTS\\E-commerce shipping data\\Train.csv")

# %%
data.head(10)
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
# 5   6               F           Flight                    3                1
# 6   7               D           Flight                    3                4
# 7   8               F           Flight                    4                1
# 8   9               A           Flight                    3                4
# 9  10               B           Flight                    3                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
data.describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# ...

# %%
data[data['Customer_rating']==5].count()
# Out:
# ID                     2171
# Warehouse_block        2171
# Mode_of_Shipment       2171
# Customer_care_calls    2171
# Customer_rating        2171
# Cost_of_the_Product    2171
# Prior_purchases        2171
# Product_importance     2171
# Gender                 2171
# Discount_offered       2171
# Weight_in_gms          2171
# Reached.on.Time_Y.N    2171
# dtype: int64

# %%
data[data['Customer_rating']==4].count()
# Out:
# ID                     2189
# Warehouse_block        2189
# Mode_of_Shipment       2189
# Customer_care_calls    2189
# Customer_rating        2189
# Cost_of_the_Product    2189
# Prior_purchases        2189
# Product_importance     2189
# Gender                 2189
# Discount_offered       2189
# Weight_in_gms          2189
# Reached.on.Time_Y.N    2189
# dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
#        'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
#        'Product_importance', 'Gender', 'Discount_offered', 'Weight_in_gms',
#        'Reached.on.Time_Y.N'],
#       dtype='object')

# %%
data['Customer_rating'].value_counts()
# Out:
# 3    2239
# 1    2235
# 4    2189
# 5    2171
# 2    2165
# Name: Customer_rating, dtype: int64

# %% [markdown]
# There are 5 categories of warehouse blocks in the data being provided.
#
# The names of the blocks are repesented in alphabetical format - A, B, C, D, F

# %%
data['Warehouse_block'].value_counts()
# Out:
# F    3666
# D    1834
# B    1833
# A    1833
# C    1833
# Name: Warehouse_block, dtype: int64

# %% [markdown]
# The number of products deivered by the mode of transport

# %%
data['Mode_of_Shipment'].value_counts()
# Out:
# Ship      7462
# Flight    1777
# Road      1760
# Name: Mode_of_Shipment, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# F    5545
# M    5454
# Name: Gender, dtype: int64

# %%
data.rename(columns={'Reached.on.Time_Y.N' : 'Reached_on_time'}, inplace=False)
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
data['Reached.on.Time_Y.N'].value_counts()
# Out:
# 1    6563
# 0    4436
# Name: Reached.on.Time_Y.N, dtype: int64

# %%
data[(data['Warehouse_block']=='A')&(data['Reached.on.Time_Y.N']==0)].count()
# Out:
# ID                     758
# Warehouse_block        758
# Mode_of_Shipment       758
# Customer_care_calls    758
# Customer_rating        758
# Cost_of_the_Product    758
# Prior_purchases        758
# Product_importance     758
# Gender                 758
# Discount_offered       758
# Weight_in_gms          758
# Reached.on.Time_Y.N    758
# dtype: int64

# %%
data[(data['Warehouse_block']=='B')&(data['Reached.on.Time_Y.N']==0)].value_counts()
# Out:
# ID     Warehouse_block  Mode_of_Shipment  Customer_care_calls  Customer_rating  Cost_of_the_Product  Prior_purchases  Product_importance  Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 3136   B                Road              6                    5                141                  3                medium              M       8                 5031           0                      1
# 8362   B                Flight            4                    1                234                  6                low                 M       7                 1711           0                      1
# 8374   B                Flight            2                    1                168                  4                low                 M       6                 4800           0                      1
# ...

# %%
data[(data['Warehouse_block']=='C')&(data['Reached.on.Time_Y.N']==0)].value_counts()
# Out:
# ID     Warehouse_block  Mode_of_Shipment  Customer_care_calls  Customer_rating  Cost_of_the_Product  Prior_purchases  Product_importance  Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 3137   C                Road              3                    3                219                  3                low                 M       4                 5956           0                      1
# 8531   C                Ship              5                    2                181                  3                low                 M       4                 4323           0                      1
# 8447   C                Ship              3                    1                209                  2                low                 F       2                 4855           0                      1
# ...

# %%
data[(data['Warehouse_block']=='D')&(data['Reached.on.Time_Y.N']==0)].value_counts()
# Out:
# ID     Warehouse_block  Mode_of_Shipment  Customer_care_calls  Customer_rating  Cost_of_the_Product  Prior_purchases  Product_importance  Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 3139   D                Road              4                    5                225                  4                medium              M       5                 4622           0                      1
# 8473   D                Road              3                    3                227                  3                medium              M       3                 5644           0                      1
# 8371   D                Flight            3                    3                163                  3                medium              M       5                 5362           0                      1
# ...

# %%
data[(data['Warehouse_block']=='F')&(data['Reached.on.Time_Y.N']==0)].value_counts()
# Out:
# ID     Warehouse_block  Mode_of_Shipment  Customer_care_calls  Customer_rating  Cost_of_the_Product  Prior_purchases  Product_importance  Gender  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 3138   F                Road              4                    3                161                  3                high                M       7                 4245           0                      1
# 8402   F                Ship              3                    3                151                  3                medium              F       1                 5297           0                      1
# 8442   F                Ship              3                    1                132                  2                medium              M       2                 4129           0                      1
# ...

# %% [markdown]
# Delays in the delivery of the packages is caused by the following warehouses
#
# A has delayed the 41.35% of its packages
#
# B has delayed the 39.77% of its packages
#
# C has delayed the 40.31% of its packages
#
# D has delayed the 40.26% of its packages
#
# F has delayed the 40.15% of its packages

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The following graphical visualization shows the relation between the customer's rating and the product's costing.

# %%
sns.barplot(x='Customer_rating', y='Cost_of_the_Product', palette='icefire', data=data, hue='Gender')
# Out:
# <AxesSubplot:xlabel='Customer_rating', ylabel='Cost_of_the_Product'>

# %% [markdown]
# The following graphical visualization shows the relation between the Mode of shipment and whether the product is reached on time to the customer.

# %%
sns.barplot(x='Mode_of_Shipment', y='Reached.on.Time_Y.N', data=data, palette='mako')
# Out:
# <AxesSubplot:xlabel='Mode_of_Shipment', ylabel='Reached.on.Time_Y.N'>

# %% [markdown]
# The following graphical visualization shows the relation between the gender and the product's costing.

# %%
sns.barplot(x='Gender', y='Cost_of_the_Product', data=data, palette='rocket')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Cost_of_the_Product'>

# %% [markdown]
# The following graphical visualization shows the relation between the different Warehouse blocks and the products reached on the time. This shows which warehouse block has performed well in the delivering the product on time.

# %%
sns.barplot(x='Warehouse_block', y='Reached.on.Time_Y.N', data=data, palette='rocket')
# Out:
# <AxesSubplot:xlabel='Warehouse_block', ylabel='Reached.on.Time_Y.N'>

# %%
sns.barplot(x='Customer_rating',y='Prior_purchases',data=data, palette="ch:s=.25,rot=-.25")
# Out:
# <AxesSubplot:xlabel='Customer_rating', ylabel='Prior_purchases'>

# %% [markdown]
# The graphical representation below shows us the relation between the weight of the product and the cost of the product and by observing it we can see that as the lower the weight higher is the cost. Even though their are certain products which weigh higher and also cost high.

# %%
sns.jointplot(x="Weight_in_gms", y="Cost_of_the_Product", data=data, kind='hex')

# %% [markdown]
# The following representation shows that the products which cost around 250 are given the dicounts in the range of 0-10%.

# %%
sns.displot(x='Cost_of_the_Product',y='Discount_offered', data=data, kind='kde', palette="light:#5A9", fill=True)

# %%
sns.clustermap(data.corr(),annot=True,cmap='cividis')

# %% [markdown]
# After observing the following the study of the provided data shows that the majority of the products are delivered by the ship and then the next mode of transport used most after the ships are roads.

# %%
plt.figure(figsize=(10,6))
data[data['Mode_of_Shipment']=='Flight']['Cost_of_the_Product'].hist(alpha=0.5,color='blue',bins=30,label='Flight')
data[data['Mode_of_Shipment']=='Road']['Cost_of_the_Product'].hist(alpha=0.5,color='red',bins=30,label='Road')
data[data['Mode_of_Shipment']=='Ship']['Cost_of_the_Product'].hist(alpha=0.5,color='grey',bins=30,label='Ship')
plt.xlabel('COST')
plt.legend()
